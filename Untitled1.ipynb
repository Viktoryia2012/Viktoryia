# %%
book = {
    "автор": "А. С. Пушкин",
    "название": "Евгений Онегин",
    "год издания": 1833,
    "жанр": "роман в стихах"
}

print(f"Название: {book['название']}, Автор: {book['автор']}, Год: {book['год издания']}, Жанр: {book['жанр']}")
# Out:
# Название: Евгений Онегин, Автор: А. С. Пушкин, Год: 1833, Жанр: роман в стихах
